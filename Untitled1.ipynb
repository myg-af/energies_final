# %%
from data.get_data import get_data

# %%
get_data('cities')
# Out:
# successfully connected to final_project
# [(1, 'AMBÉRIEU-EN-BUGEY'),
#  (2, 'AMBRONAY'),
#  (3, 'ANGLEFORT'),
#  (4, 'ARANC'),
#  (5, 'ARBENT'),
#  (6, 'ATTIGNAT'),
#  (7, 'BÂGÉ-DOMMARTIN'),
#  (8, 'BÂGÉ-LE-CHÂTEL'),
#  (9, 'BALAN'),
#  (10, 'BEAUREGARD'),
#  (11, 'BELLIGNAT'),
#  (12, 'BÉLIGNEUX'),
#  (13, 'BELLEGARDE-SUR-VALSERINE'),
#  (14, 'BELLEY'),
#  (15, 'BÉNY'),
#  (16, 'BÉON'),
#  (17, 'BETTANT'),
#  (18, 'BEYNOST'),
#  (19, 'BILLIAT'),
#  (20, 'BLYES'),
#  (21, 'LA BOISSE'),
#  (22, 'BOLOZON'),
#  (23, 'BOURG-EN-BRESSE'),
#  (24, 'BRÉGNIER-CORDON'),
#  (25, 'BRÉNOD'),
#  (26, 'BRESSOLLES'),
#  (27, 'BRION'),
#  (28, 'BRIORD'),
#  (29, 'BUELLAS'),
#  (30, 'CERTINES'),
#  (31, 'CESSY'),
#  (32, 'CEYZÉRIAT'),
#  (33, 'CHALAMONT'),
#  (34, 'CHALEINS'),
#  (35, 'CHALLEX'),
#  (36, 'CHAMPFROMIER'),
#  (37, 'CHANAY'),
#  (38, 'CHARNOZ-SUR-AIN'),
#  (39, 'CHÂTEAU-GAILLARD'),
#  (40, 'CHÂTILLON-EN-MICHAILLE'),
#  (41, 'CHÂTILLON-SUR-CHALARONNE'),
#  (42, 'CHAVEYRIAT'),
# ...

# %%
get_data('energies')
# Out:
# successfully connected to final_project
# [(1, 'E'), (2, 'G')]

# %%
get_data('operators')
# Out:
# successfully connected to final_project
# [(1, 'Enedis'), (2, 'RTE'), (3, 'GRDF'), (4, 'GRT_GAZ'), (5, 'Teréga')]

# %%
get_data('deliveries')
# Out:
# successfully connected to final_project
# [(1, 2018, '010040101', '1,073901e+02', '82  RUE DES MOUETTES', 2, 3, 2, 1),
#  (2, 2018, '010040101', '1,151224e+02', '84  RUE DES MOUETTES', 2, 3, 2, 1),
#  (3,
#   2018,
#   '010040101',
#   '1,236034e+03',
#   '36  ALLEE DE LA BARBOTIERE',
#   3,
#   3,
#   2,
#   1),
#  (4, 2018, '010040101', '1,487440e+03', 'AVENUE LEON BLUM', 3, 3, 2, 1),
#  (5,
#   2018,
#   '010040101',
#   '1,595118e+02',
#   '54  AVENUE PAUL PAINLEVE',
#   2,
#   3,
#   2,
#   1),
#  (6, 2018, '010040101', '100,20363', '625 AVENUE LEON BLUM', 3, 1, 1, 1),
#  (7, 2018, '010040101', '107,48848', '648 AVENUE LEON BLUM', 3, 1, 1, 1),
#  (8, 2018, '010040101', '109,27434', '71 AVENUE DE LA LIBERATION', 3, 1, 1, 1),
#  (9, 2018, '010040101', '11,53491', '65 AVENUE DE LA LIBERATION', 3, 1, 1, 1),
#  (10, 2018, '010040101', '110,86756', '90 AVENUE DE VERDUN', 2, 1, 1, 1),
#  (11, 2018, '010040101', '160,5505', '813 AVENUE LEON BLUM', 3, 1, 1, 1),
# ...

# %%
get_data('sectors')
# Out:
# successfully connected to final_project
# [(1, 'I'), (2, 'R'), (3, 'T'), (4, 'A'), (5, 'X')]

# %%
get_data('addresses')
# Out:
# successfully connected to final_project
# [(1, '2 RUE DE VILLENEUVE', 375),
#  (2, '8 RUE PIERRE ET MARIE CURIE', 5),
#  (3, '80  CHEMIN DES MAURES', 561),
#  (4, '2 RUE PAUL STRAUSS', 375),
#  (5, '44 RUE DU PIC MAR', 119),
#  (6, 'AVENUE DU GENERAL LECLERC', 916),
#  (7, '16  ALLEE DE LA TULIPE NOIRE', 403),
#  (8, '18 RUE MONTESQUIEU', 23),
#  (9, 'SAINT JULIEN D EMPARE', 955),
#  (10, 'RUE DE FLANDRE', 766),
#  (11, '99 RUE DE LA CLAIE', 366),
#  (12, 'RTE ROQUEFIXADE', 825),
#  (13, '52  RUE AUGUSTE PEGURIER', 690),
#  (14, '4 RUE GEOFFROY SAINT HILAIRE', 366),
#  (15, '5 PLACE D OBBOURG', 175),
#  (16, '9  AVENUE OTMUS', 228),
#  (17, '2 PLACE DU ROCHASSON', 540),
#  (18, '2 QUAI LOUIS BLANC', 459),
#  (19, '45  BOULEVARD TZAREWITCH', 690),
#  (20, '181 ROUTE DE RILLIEUX', 98),
#  (21, '15  RUE MARIE NOEL', 855),
#  (22, '43 BOULEVARD D OXFORD', 578),
#  (23, '15  AVENUE URBAIN BOSIO', 690),
#  (24, '42 BOULEVARD BIJOU PLAGE', 561),
#  (25, '31 AVENUE DE NICE', 561),
# ...
