# %%
import requests
import bs4

# %%
url = "https://forum.doctissimo.fr/sante"
response = requests.get(url).text
soup = bs4.BeautifulSoup(response, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"
# 		"https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html lang="fr" xml:lang="fr" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="" name="viewport"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <title>
#    Page inexistante (404) - Club doctissimo
#   </title>
#   <meta content="Les forums de Doctissimo sont des lieux de discussion, d'échange et de partage autour de questions medicales... Cancer, diabete, maladies cardio-vasculaires, asthme, cholesterol, contraception, depression, fatigue, grippe, jambes lourdes, migraine, sida, thyroide, obesite, troubles de l'erection..." name="description"/>
# ...

# %%
for page_number in range (1,223):
    my_url = response + str(page_number)
    print(my_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"
# 		"https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml" xml:lang="fr" lang="fr">
# <head>
# 	<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
# 	<meta name="viewport"
# 		  content=""/>
# 	<meta name="robots" content="noindex, nofollow"/>
# 	<title>Page inexistante (404) - Club doctissimo</title>
#
# ...

# %%
page_soup = soup(page_html, "html.parser")

containers = page_soup.findAll("div",{"class":""})

    for x in containers:
        name = x.a.text
        refuge_name = x.find("span", {"class":"refuge-name"}).a.text

    print("name: " + name)
    print("refuge_name: " + refuge_name)
