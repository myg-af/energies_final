# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
import pandas as pd

# %%
url = requests.get("https://www.la-spa.fr/adopter-animaux?page=").text
print(url)
# Out:
# <!DOCTYPE html>
# <html lang="fr" dir="ltr"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:article="http://ogp.me/ns/article#"
#   xmlns:book="http://ogp.me/ns/book#"
#   xmlns:profile="http://ogp.me/ns/profile#"
#   xmlns:video="http://ogp.me/ns/video#"
#   xmlns:product="http://ogp.me/ns/product#"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"
#   xmlns:dc="http://purl.org/dc/terms/"
#   xmlns:foaf="http://xmlns.com/foaf/0.1/"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:sioct="http://rdfs.org/sioc/types#"
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns="http://www.w3.org/1999/xhtml"  prefix="og: http://ogp.me/ns#">
#     <head>
#         <title>Société Protectrice des Animaux</title>
#         <meta charset="utf-8"/>
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#         <meta name="format-detection" content="telephone=no"/>
# ...

# %%
url = "https://www.la-spa.fr/adopter-animaux?page="
def get_pages(url, nb):
    pages = []
    for page in range(1,nb+1):
        j = url + str(page)
        pages.append(j)
    return pages

pages = get_pages(url,201)

print(pages)
# Out:
# ['https://www.la-spa.fr/adopter-animaux?page=1', 'https://www.la-spa.fr/adopter-animaux?page=2', 'https://www.la-spa.fr/adopter-animaux?page=3', 'https://www.la-spa.fr/adopter-animaux?page=4', 'https://www.la-spa.fr/adopter-animaux?page=5', 'https://www.la-spa.fr/adopter-animaux?page=6', 'https://www.la-spa.fr/adopter-animaux?page=7', 'https://www.la-spa.fr/adopter-animaux?page=8', 'https://www.la-spa.fr/adopter-animaux?page=9', 'https://www.la-spa.fr/adopter-animaux?page=10', 'https://www.la-spa.fr/adopter-animaux?page=11', 'https://www.la-spa.fr/adopter-animaux?page=12', 'https://www.la-spa.fr/adopter-animaux?page=13', 'https://www.la-spa.fr/adopter-animaux?page=14', 'https://www.la-spa.fr/adopter-animaux?page=15', 'https://www.la-spa.fr/adopter-animaux?page=16', 'https://www.la-spa.fr/adopter-animaux?page=17', 'https://www.la-spa.fr/adopter-animaux?page=18', 'https://www.la-spa.fr/adopter-animaux?page=19', 'https://www.la-spa.fr/adopter-animaux?page=20', 'https://www.la-spa.fr/ado
# ...

# %%
for x in pages:
    response = requests.get(x)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="fr" dir="ltr"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:article="http://ogp.me/ns/article#"
#   xmlns:book="http://ogp.me/ns/book#"
#   xmlns:profile="http://ogp.me/ns/profile#"
#   xmlns:video="http://ogp.me/ns/video#"
#   xmlns:product="http://ogp.me/ns/product#"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"
#   xmlns:dc="http://purl.org/dc/terms/"
#   xmlns:foaf="http://xmlns.com/foaf/0.1/"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:sioct="http://rdfs.org/sioc/types#"
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#" xmlns="http://www.w3.org/1999/xhtml"  prefix="og: http://ogp.me/ns#">
#     <head>
#         <title>Société Protectrice des Animaux</title>
#         <meta charset="utf-8"/>
#         <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#         <meta name="format-detection" content="telephone=no"/>
# ...

# %%
import bs4
soup = bs4.BeautifulSoup(response.text, 'html.parser')
refuge = soup.find_all("span", {"class":"refuge-name"})
#dob = soup.find_all("div", {"class":"field-item.even"})
#race = soup.find_all("span", {"class":"field-item.even"})
print(refuge)
# Out:
# [<span class="refuge-name">
# <a href="/adopter-animaux/adopter-equide-cheval-f-cornouaille-355600"><a href="https://www.la-spa.fr/adopter-animaux/adopter-equide-cheval-f-cornouaille-355600">61 - Grand Refuge SPA</a></a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-equide-cheval-f-terilene-384975"><a href="https://www.la-spa.fr/adopter-animaux/adopter-equide-cheval-f-terilene-384975">61 - Grand Refuge SPA</a></a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-equide-cheval-m-le-caroubier-363725"><a href="https://www.la-spa.fr/adopter-animaux/adopter-equide-cheval-m-le-caroubier-363725">61 - Grand Refuge SPA</a></a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-equide-cheval-f-tralala-372011"><a href="https://www.la-spa.fr/adopter-animaux/adopter-equide-cheval-f-tralala-372011">61 - Grand Refuge SPA</a></a> </span>, <span class="refuge-name">
# ...

# %%
import bs4
soup = bs4.BeautifulSoup(response.text, 'html.parser')
dob = soup.find_all("div", {"class":"field-item"})
print(dob[4])
print('Number of results', len(dob))
# Out:
# <div class="field-item even"><img alt="LE CAROUBIER - Adoptez Equidé  avec la SPA" height="375" src="https://www.la-spa.fr/sites/default/files/styles/fiche_animal_620x375/public/animals/363725.jpg?itok=k_Y4riw3" typeof="foaf:Image" width="482"/></div>
# Number of results 32

# %%
import urllib.request
import csv

# query the website and return the html to the variable 'page'
page = urllib.request.urlopen("https://www.la-spa.fr/adopter-animaux?page=1")
# parse the html using beautiful soup and store in variable 'soup'
soup = BeautifulSoup(page, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fr" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:video="http://ogp.me/ns/video#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
#  <head>
#   <title>
#    Société Protectrice des Animaux
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# ...

# %%
result = requests.get("https://www.la-spa.fr/adopter-animaux?page=1")
src = result.content
soup = BeautifulSoup(src, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fr" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:video="http://ogp.me/ns/video#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
# <head>
# <title>Société Protectrice des Animaux</title>
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
# ...

# %%
refuge = soup.find_all('span', attrs={'class': 'refuge-name'})
print(refuge)
# Out:
# [<span class="refuge-name">
# <a href="/adopter-animaux/adopter-chat-europeen-f-raquel-473072"></a><a href="https://www.la-spa.fr/adopter-animaux/adopter-chat-europeen-f-raquel-473072">76 - Refuge d'Etalondes</a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-chat-europeen-m-ray-473071"></a><a href="https://www.la-spa.fr/adopter-animaux/adopter-chat-europeen-m-ray-473071">76 - Refuge d'Etalondes</a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-chat-europeen-m-rouxi-473070"></a><a href="https://www.la-spa.fr/adopter-animaux/adopter-chat-europeen-m-rouxi-473070">76 - Refuge d'Etalondes</a> </span>, <span class="refuge-name">
# <a href="/adopter-animaux/adopter-chat-europeen-f-rowina-473069"></a><a href="https://www.la-spa.fr/adopter-animaux/adopter-chat-europeen-f-rowina-473069">76 - Refuge d'Etalondes</a> </span>, <span class="refuge-name">
# ...

# %%
net = soup.find("span", {"class":"refuge-name"})
print(net.prettify())
# Out:
# <span class="refuge-name">
#  <a href="/adopter-animaux/adopter-chat-europeen-f-raquel-473072">
#  </a>
#  <a href="https://www.la-spa.fr/adopter-animaux/adopter-chat-europeen-f-raquel-473072">
#   76 - Refuge d'Etalondes
#  </a>
# </span>

# %%
for i in range(len(soup.find_all('span',{'class':"refuge-name"}))):
    print (soup.find_all('span',{'class':"refuge-name"})[i].get_text())
# Out:
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 57 - Refuge de Thionville
#
# 57 - Refuge de Thionville
#
# 57 - Refuge de Thionville
#
# 69 - Refuge de Lyon-Marennes
#
# 11 - Maison SPA de Lézignan-Corbières
#
# 57 - Refuge de Thionville
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 77 - Refuge de Vaux Le Pénil
#
# 57 - Refuge Gerhard Cramer - Arry

# %%
soup.find_all('p')[3].get_text()
# Out:
# "Selon que vous cherchiez un chat, un chien, un NAC, un équidé…, consultez ci-dessous les profils de tous nos pensionnaires à l’adoption. Ils comptent sur vous, et nous aussi. Et surtout, n'oubliez pas..."

# %%
soup.title
# Out:
# <title>Société Protectrice des Animaux</title>

# %%
for info in soup.find_all('span',{'class':'refuge-name'}):
    print(info.text)
# Out:
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 76 - Refuge d'Etalondes
#
# 57 - Refuge de Thionville
#
# 57 - Refuge de Thionville
#
# 57 - Refuge de Thionville
#
# 69 - Refuge de Lyon-Marennes
#
# 11 - Maison SPA de Lézignan-Corbières
#
# 57 - Refuge de Thionville
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 44 - Refuge Pornic-Saint Père - Clion sur Mer
#
# 77 - Refuge de Vaux Le Pénil
#
# 57 - Refuge Gerhard Cramer - Arry

# %%
import os
import csv
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

page = "https://www.la-spa.fr/adopter-animaux?page="
filename = "spa.csv"
f = open(filename, "w")

headers = "name, refuge_name\n"
f.write(headers)

for page_number in range ( 1,223):
    my_url = page + str(page_number)
    print(my_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()

    page_soup = soup(page_html, "html.parser")

    containers = page_soup.findAll("div",{"class":"block-result-search-bottom"})

    for container in containers:
        name = container.a.text
        refuge_name = container.find("span", {"class":"refuge-name"}).a.text

    print("name: " + name)
    print("refuge_name: " + refuge_name)

    f.write(name + "," + refuge_name + "\n")
f.close()

# %%
import os
import csv
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

page = "https://www.la-spa.fr/adopter-animaux?page="
#filename = "spa.csv"
#f = open(filename, "w")

#headers = "name, refuge_name\n"
#f.write(headers)

for page_number in range ( 1,223):
    my_url = page + str(page_number)
    print(my_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()

    page_soup = soup(page_html, "html.parser")

    containers = page_soup.findAll("div",{"class":"block-result-search-bottom"})

    for container in containers:
        link = container.find('span','animal-name')
        sibling = link.find('a')#lien pour aller chercher les infos sur la seconde page
        #print(link)
    print(sibling)

    #print("name: " + name)
    #print("refuge_name: " + refuge_name)

    #f.write(name + "," + refuge_name + "\n")
#f.close()

# %%
url = "https://www.la-spa.fr/adopter-animaux?page="
def get_pages(url, nb):
    pages = []
    for page in range(1,nb+1):
        text = url + str(page)
        pages.append(text)
    return pages

pages = get_pages(url,201)

for x in pages:
    print("ma page : " + pages[pages.index(x)])
